# %% [markdown]
# jupiter_root package have all modules written, to make task in jupiter faster

# %%
import numpy as np

from jupiter_root import *
import importlib
importlib.reload(rootf)
importlib.reload(rstat)
importlib.reload(vis)
# Out:
# <module 'jupiter_root.vis' from '/mnt/share/it/pycharm/uj/rootRes1/jupiter_root/vis.py'>

# %% [markdown]
# With object 'data' we can get any array we want, all we need is write name of the file and then extract array from the branch we specify:

# %%
data = rootf.Rootf("results1_short100_coincidences.root")
time1_arr = data.get_arr("time1")
time2_arr = data.get_arr("time2")
energy1_arr = data.get_arr("energy1")
energy2_arr = data.get_arr("energy2")

# %% [markdown]
# First task: visualisation of distributions

# %%
vis.plt_arr(time1_arr)
vis.plt_arr(time2_arr)
vis.plt_arr(energy1_arr)
vis.plt_arr(energy2_arr)

# %% [markdown]
# Second task: get mmm from energy1 and energy2

# %%
print('energy1:')
rstat.mmm(energy1_arr)
print('energy2:')
rstat.mmm(energy2_arr)
print(type(energy2_arr))
# Out:
# energy1:
# minimum: 0.2000238448381424
# median: 0.27991482615470886
# maximum: 0.3718954622745514
# energy2:
# minimum: 0.20179855823516846
# median: 0.26921898126602173
# maximum: 0.40886762738227844
# <class 'awkward.highlevel.Array'>

# %%
vis.distribution_arr(energy1_arr)
vis.distribution_arr(energy2_arr)
vis.distribution_arr(time1_arr)
vis.distribution_arr(time2_arr)
# Out:
# minimum: 0.2000238448381424
# dx: 0.0171871617436409
# 100
# 0.20861742570996286 0.22580458745360377 0.24299174919724464 0.2601789109408856 0.27736607268452645 0.29455323442816733 0.3117403961718082 0.32892755791544914 0.3461147196590901 0.36330188140273095
# 15 17 5 6 11 7 11 14 8 6
# 100
# minimum: 0.20179855823516846
# dx: 0.020706906914711
# 100
# 0.21215201169252396 0.23285891860723495 0.25356582552194595 0.27427273243665695 0.29497963935136795 0.31568654626607895 0.33639345318078995 0.35710036009550095 0.37780726701021194 0.39851417392492294
# 21 13 10 15 15 11 10 4 0 1
# 100
# minimum: 6.738641626158545e-07
# dx: 9.568466038282822e-06
# 100
# 5.4580971817572645e-06 1.5026563220040086e-05 2.4595029258322908e-05 3.416349529660573e-05 4.373196133488855e-05 5.330042737317137e-05 6.286889341145419e-05 7.243735944973702e-05 8.200582548801983e-05 9.157429152630267e-05
# 7 13 9 8 10 15 10 7 12 9
# 100
# minimum: 6.744110535611187e-07
# dx: 9.568455087651642e-06
# 100
# ...
